# %%
import pandas 
import numpy as np

# %%
data1 = pandas.read_csv(r'C:\Users\LENOVO\Desktop\LegalMind-AI\LegalMind-AI\data\csv\egyptian_labor_law_2025.csv')
data1.head()
# Out:
#   Arabic Number  English Number Arabic Article  Article Number (EN)  \
# 0             1               1     مادة (1) :                  1.0
# 1             ٢               2     مادة (٢) :                  2.0
# 2             ۳               3      مادة (۳):                  3.0
# 3             ٤               4     مادة (٤) :                  4.0
# 4             5               5     مادة (5) :                  5.0
#
#                                                 Text
# 0  يقصد فى تطبيق أحكام هذا القانون بالكلمات والمص...
# 1  فى تطبيق أحكام هذا القانون تعتبر السنة ( ٣٦٥) ...
# 2  يُعتبر هذا القانون هو القانون العام الذى يحكم ...
# 3  يُحظر تشغيل العامل سخرة أو جبرًا ، كما يُحظر ا...
# 4  يُحظر كل عمل أو سلوك أو إجراء يكون من شأنه إحد...

# %%
data = pandas.read_csv(r'C:\Users\LENOVO\Desktop\LegalMind-AI\LegalMind-AI\data\csv\egyptian_constitution.csv')
data.head()
# Out:
#   Arabic Number  English Number Arabic Article Article Number (EN)  \
# 0             ٧               7       الديباجة            Preamble
# 1            ١٢              12       مادة (1)                   1
# 2            ١٢              12       مادة (2)                   2
# 3            ١٢              12       مادة (3)                   3
# 4            ١٢              12       مادة (4)                   4
#
#                                                 Text
# 0  بسم الله الرحمن الرحيم\n\nهذا دستورنا\n\nمصر ه...
# 1  جمهورية مصر العربية دولة ذات سيادة» موحدة لا ت...
# 2  الإسلام دين الدولة» واللغة العربية لغتها الرسم...
# 3  مبادئ شرائع المصريين من المسيحيين واليهود المص...
# 4  السيادة للشعب وحده؛ يمارسها ويحميهاء وهو مصدر ...
